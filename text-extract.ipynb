# %%
from dotenv import load_dotenv
load_dotenv()

from pathlib import Path
import boto3
import json
import yaml

# %%
# Out:
# [PosixPath('output/27-18 - TESLA OPENING - 257 ppl attending/04 - text/01-2-back.txt'),
#  PosixPath('output/27-18 - TESLA OPENING - 257 ppl attending/04 - text/02-2-back.txt'),
#  PosixPath('output/27-18 - TESLA OPENING - 257 ppl attending/04 - text/03-2-back.txt'),
#  PosixPath('output/27-18 - TESLA OPENING - 257 ppl attending/04 - text/04-2-back.txt'),
#  PosixPath('output/27-18 - TESLA OPENING - 257 ppl attending/04 - text/05-2-back.txt'),
#  PosixPath('output/27-18 - TESLA OPENING - 257 ppl attending/04 - text/06-2-back.txt'),
#  PosixPath('output/27-18 - TESLA OPENING - 257 ppl attending/04 - text/07-2-back.txt'),
#  PosixPath('output/27-18 - TESLA OPENING - 257 ppl attending/04 - text/08-2-back.txt'),
#  PosixPath('output/27-18 - TESLA OPENING - 257 ppl attending/04 - text/09-2-back.txt'),
#  PosixPath('output/27-18 - TESLA OPENING - 257 ppl attending/04 - text/10-2-back.txt'),
#  PosixPath('output/27-18 - TESLA OPENING - 257 ppl attending/04 - text/11-2-back.txt'),
# ...
